# %% [markdown]
# # Data Analysis Shark Attacks
# ## Working Paper by Armaan Rampal
# ### November 15th 2023

# %% [markdown]
# ---

# %% [markdown]
# ## Introduction

# %% [markdown]
# ---

# %% [markdown]
# ## Module & Library Imports

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
#Hashtags imply comments in python
#Import Gapminder
#gm_df = pandas.read_csv('gapminder.tsv',
#sep='\t')
#print ("The shape of dimensions of the Gapminder Data are:", gm_df.shape)

#Import TFL Bus Safety
#tfl_df = pd.read_excel('./data/TFL_Bus_Safety.xlsx')
#tfl_df = pd.read_excel('/workspaces/codespaces-blank/myJupyter/data/TFL_Bus_Safety.xlsx')

tfl_df = pd.read_excel('./data/TFL_Bus_Safety.xlsx')

print ("The shape of dimensions of the Bus Safety Data are:", tfl_df.shape)
print ("---")
print ("The types of the columns of the Bus Safety Data are:","\n\r",tfl_df.dtypes)
#Import Shark Attacks
#Shark_df = pandas.read_csv('./data/shark_attacks.csv')
#print ("The shape or dimensions of the Shark Data are:", Shark_df.shape)

# Import Happiness Index
#Happiness_Index_df = pandas.read_csv('./data/Happiness_Index.csv')
#print ("The shape of dimensions of the Happiness Data are:", Happiness_Index_df.shape)
# Out:
# The shape of dimensions of the Bus Safety Data are: (23158, 12)
# ---
# The types of the columns of the Bus Safety Data are:
#  Year                                  int64
# Date Of Incident             datetime64[ns]
# Route                                object
# Operator                             object
# Group Name                           object
# Bus Garage                           object
# Borough                              object
# Injury Result Description            object
# Incident Event Type                  object
# Victim Category                      object
# Victims Sex                          object
# Victims Age                          object
# dtype: object

# %%
#Sorting 
tfl_df.sort_values(by = "Borough", ascending = True)
# Out:
#        Year Date Of Incident Route             Operator     Group Name  \
# 7349   2016       2016-12-01     5          East London     Stagecoach
# 13314  2017       2017-04-01     5          East London     Stagecoach
# 5589   2015       2015-12-01   287          East London     Stagecoach
# 13878  2017       2017-05-01     5          East London     Stagecoach
# 720    2015       2015-04-01   287          East London     Stagecoach
# ...     ...              ...   ...                  ...            ...
# 21968  2018       2018-07-01   274            Metroline      Metroline
# 13897  2017       2017-05-01    13        Tower Transit  Tower Transit
# 4860   2015       2015-11-01    98            Metroline      Metroline
# 2293   2015       2015-03-01    11       London General       Go-Ahead
# 6869   2016       2016-11-01    59  Arriva London South  Arriva London
#
#                         Bus Garage             Borough  \
# 7349   Barking (East London Buses)  Barking & Dagenham
# ...

# %%
#Filtering 
tfl_df[tfl_df["Borough"] != "Croydon"]
# Out:
#        Year Date Of Incident    Route        Operator     Group Name  \
# 0      2015       2015-01-01        1  London General       Go-Ahead
# 1      2015       2015-01-01        4       Metroline      Metroline
# 2      2015       2015-01-01        5     East London     Stagecoach
# 3      2015       2015-01-01        5     East London     Stagecoach
# 4      2015       2015-01-01        6       Metroline      Metroline
# ...     ...              ...      ...             ...            ...
# 23153  2018       2018-09-01  (blank)     East London     Stagecoach
# 23154  2018       2018-09-01  (blank)   London United  London United
# 23155  2018       2018-09-01  (blank)   London United  London United
# 23156  2018       2018-09-01  (blank)   London United  London United
# 23157  2018       2018-09-01  (blank)       Metroline      Metroline
#
#                  Bus Garage               Borough  \
# 0      Garage Not Available             Southwark
# ...

# %%
# List values in a column

# tfl_df["Victim Category"].tolist()

tfl_df["Victim Category"].unique()
# Out:
# array(['Passenger', 'Pedestrian', 'Conductor', 'Bus Driver',
#        'Member Of Public', 'Cyclist', 'Motorcyclist',
#        '3rd Party driver / Occupant', 'Other', 'Non-Operational Staff',
#        'Operational Staff', 'Contractor Staff', 'TfL Staff',
#        'Operations staff (other)', 'Cyclist ', 'Motorcyclist ',
#        'Insufficient Data'], dtype=object)

# %%
# List values in a column

# tfl_df["Victim Category"].tolist()

tfl_df["Borough"].unique()
# Out:
# array(['Southwark', 'Islington', 'Havering', 'None London Borough',
#        'Westminster', 'City of London', 'Hammersmith & Fulham',
#        'Kensington & Chelsea', 'Brent', 'Camden', 'Hounslow',
#        'Richmond Upon Thames', 'Enfield', 'Waltham Forest', 'Wandsworth',
#        'Hackney', 'Barnet', 'Lambeth', 'Lewisham', 'Croydon', 'Bexley',
#        'Kingston upon Thames', 'Merton', 'Bromley', 'Haringey', 'Ealing',
#        'Hillingdon', 'Newham', 'Harrow', 'Sutton', 'Greenwich',
#        'Redbridge', 'Tower Hamlets', 'Barking & Dagenham',
#        'Not specified'], dtype=object)

# %%
# May have to replace the spelling of Cyclist that has an extra space.
tfl_df['Victim Category'].replace('Cyclist ','Cyclist',inplace=True)
tfl_df["Victim Category"].unique()
# Out:
# array(['Passenger', 'Pedestrian', 'Conductor', 'Bus Driver',
#        'Member Of Public', 'Cyclist', 'Motorcyclist',
#        '3rd Party driver / Occupant', 'Other', 'Non-Operational Staff',
#        'Operational Staff', 'Contractor Staff', 'TfL Staff',
#        'Operations staff (other)', 'Motorcyclist ', 'Insufficient Data'],
#       dtype=object)

# %%
#

#tfl_df["Victim Category"].value_counts().head(50)
#tfl_df["Victim Category"].value_counts().head(50).plot()
plt.plot(tfl_df["Victim Category"].value_counts().head(50), color='blue', linestyle='solid')

plt.xlabel("Victim Category", size=12)
plt.ylabel("Occurence", size=12)

# Rotating X-axis labels
plt.xticks(rotation = 60)
 
# Setting title
plt.title('Armaan Rampal Analysis')
 
# Show plot
plt.show()

# %%
# Print the 100th row
# movies["Studio"].value_counts().head(10)

tfl_df["Borough"].value_counts().head(50)

# Exercise. Using the example above, make a plot for the data set below.
# Out:
# Westminster             1571
# Lambeth                 1107
# Southwark               1107
# Croydon                 1032
# Lewisham                1006
# Barnet                   922
# Camden                   900
# Brent                    887
# Ealing                   863
# Greenwich                832
# Haringey                 831
# Hackney                  796
# Islington                769
# Bromley                  673
# Havering                 652
# Hounslow                 642
# Newham                   634
# Hammersmith & Fulham     632
# Enfield                  584
# None London Borough      561
# Not specified            553
# Wandsworth               551
# Waltham Forest           526
# Hillingdon               517
# Redbridge                470
# Kingston upon Thames     451
# Tower Hamlets            435
# Bexley                   414
# Richmond Upon Thames     403
# Harrow                   384
# Barking & Dagenham       374
# Kensington & Chelsea     334
# ...

# %%
# Print the 100th row

tfl_df["Operator"].value_counts().head(50)

# Exercise. Using the exmample above repeat for data set below.
# Out:
# Metroline                3457
# Arriva London North      3208
# East London              2402
# London United            2263
# Selkent                  1808
# Arriva London South      1743
# London General           1723
# London Central           1367
# Metroline West           1232
# Abellio London            963
# Metrobus                  786
# Tower Transit             738
# Arriva The Shires         305
# Blue Triangle Buses       281
# London Sovereign          206
# Quality Line              142
# Abellio West              126
# Arriva Kent Thameside     107
# Docklands Buses           100
# C T Plus                   77
# TGM GROUP                  61
# H R Richmond               59
# Sullivan Buses              2
# Uno Buses                   1
# Sullivan Bus & Coach        1
# Name: Operator, dtype: int64

# %%
# Print the 100th row
# movies["Studio"].value_counts().head(10)
tfl_df["Victims Age"].value_counts().head(50)
# Out:
# Adult      10754
# Unknown     7135
# Elderly     2769
# Child       2181
# Youth        319
# Name: Victims Age, dtype: int64

# %% [markdown]
# ## Data Analysis

# %% [markdown]
# ## Conclusion
